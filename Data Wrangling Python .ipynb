# %% [markdown]
# # Buatkan summary dari data yang ada

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('data_penguin.csv - data_penguin.csv.csv')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Lakukan filter dengan syarat island adalah Torgersen

# %%
f_df = df[(df["island"] == "Torgersen")]

# %%
f_df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# # Urutkan data berdasarkan column culmen_length_mm dari yang kecil ke yang terbesar

# %%
df.sort_values(by=["culmen_length_mm"])
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 142     Adelie      Dream              32.1             15.5
# 98      Adelie      Dream              33.1             16.1
# 70      Adelie  Torgersen              33.5             19.0
# 92      Adelie      Dream              34.0             17.1
# 8       Adelie  Torgersen              34.1             18.1
# ..         ...        ...               ...              ...
# 321     Gentoo     Biscoe              55.9             17.0
# 169  Chinstrap      Dream              58.0             17.8
# 253     Gentoo     Biscoe              59.6             17.0
# 3       Adelie  Torgersen               NaN              NaN
# 339     Gentoo     Biscoe               NaN              NaN
#
#      flipper_length_mm  body_mass_g     sex
# 142              188.0       3050.0  FEMALE
# 98               178.0       2900.0  FEMALE
# 70               190.0       3600.0  FEMALE
# 92               185.0       3400.0  FEMALE
# ...

# %% [markdown]
# # Urutkan data berdasarkan column Island dari A-Z

# %%
df.sort_values(by=["island"])
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 343  Gentoo     Biscoe              49.9             16.1              213.0
# 108  Adelie     Biscoe              38.1             17.0              181.0
# 109  Adelie     Biscoe              43.2             19.0              197.0
# 110  Adelie     Biscoe              38.1             16.5              198.0
# 111  Adelie     Biscoe              45.6             20.3              191.0
# ..      ...        ...               ...              ...                ...
# 72   Adelie  Torgersen              39.6             17.2              196.0
# 71   Adelie  Torgersen              39.7             18.4              190.0
# 70   Adelie  Torgersen              33.5             19.0              190.0
# 68   Adelie  Torgersen              35.9             16.6              190.0
# 0    Adelie  Torgersen              39.1             18.7              181.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # Tunjukan jenis-jenis spesies penguin yang ada

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# # Hitung total untuk masing-masing island dan tunjukan island terbanyak dan terendah

# %%
df["island"].count()
# Out:
# 344

# %%
df["island"].min()
# Out:
# 'Biscoe'

# %%
df["island"].max()
# Out:
# 'Torgersen'

# %% [markdown]
# # Lakukan pemilihan variable dengan kriteria species, flipper_length_mm, sex dan tunjukan 25 data teratas

# %%
sort = df[["species", "flipper_length_mm", "sex"]]
sort.head(25)
# Out:
#    species  flipper_length_mm     sex
# 0   Adelie              181.0    MALE
# 1   Adelie              186.0  FEMALE
# 2   Adelie              195.0  FEMALE
# 3   Adelie                NaN     NaN
# 4   Adelie              193.0  FEMALE
# 5   Adelie              190.0    MALE
# 6   Adelie              181.0  FEMALE
# 7   Adelie              195.0    MALE
# 8   Adelie              193.0     NaN
# 9   Adelie              190.0     NaN
# 10  Adelie              186.0     NaN
# 11  Adelie              180.0     NaN
# 12  Adelie              182.0  FEMALE
# 13  Adelie              191.0    MALE
# 14  Adelie              198.0    MALE
# 15  Adelie              185.0  FEMALE
# 16  Adelie              195.0  FEMALE
# 17  Adelie              197.0    MALE
# 18  Adelie              184.0  FEMALE
# 19  Adelie              194.0    MALE
# 20  Adelie              174.0  FEMALE
# 21  Adelie              180.0    MALE
# 22  Adelie              189.0  FEMALE
# 23  Adelie              185.0    MALE
# ...

# %% [markdown]
# # Lakukan filter data dengan syarat species Gentoo, island dream

# %%
f_data = df[(df["species"] == "Gentoo") | (df["island"] == "Dream")]
f_data
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 30   Adelie   Dream              39.5             16.7              178.0
# 31   Adelie   Dream              37.2             18.1              178.0
# 32   Adelie   Dream              39.5             17.8              188.0
# 33   Adelie   Dream              40.9             18.9              184.0
# 34   Adelie   Dream              36.4             17.0              195.0
# ..      ...     ...               ...              ...                ...
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 30        3250.0  FEMALE
# 31        3900.0    MALE
# ...

# %% [markdown]
# # Lakukan pengecekan outlier pada variabel flipper_length_mm menggunakan boxplot

# %%
df[['flipper_length_mm']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Lakukan pengecekan distribusi pada variabel flipper_length_mm menggunakan histogram

# %%
df[['flipper_length_mm']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'flipper_length_mm'}>]], dtype=object)

# %% [markdown]
# # Lakukan grouping berdasarkan spesies kemudian cari nilai rata-rata untuk body_mass_g

# %%
df.groupby(['body_mass_g']).mean()
# Out:
#              culmen_length_mm  culmen_depth_mm  flipper_length_mm
# body_mass_g
# 2700.0              46.900000        16.600000              192.0
# 2850.0              36.450000        16.850000              182.5
# 2900.0              37.350000        16.950000              185.0
# 2925.0              37.900000        18.600000              193.0
# 2975.0              37.500000        18.900000              179.0
# ...                       ...              ...                ...
# 5850.0              50.933333        15.433333              220.0
# 5950.0              47.500000        16.150000              226.0
# 6000.0              49.950000        16.250000              221.0
# 6050.0              59.600000        17.000000              230.0
# 6300.0              49.200000        15.200000              221.0
#
# [94 rows x 3 columns]

# %% [markdown]
# # Lakukan grouping berdasarkan spesies dan island kemudian cari nilai rata-rata untuk culmen_length_mm

# %%
df.groupby(['culmen_length_mm']).mean()
# Out:
#                   culmen_depth_mm  flipper_length_mm  body_mass_g
# culmen_length_mm
# 32.1                         15.5              188.0       3050.0
# 33.1                         16.1              178.0       2900.0
# 33.5                         19.0              190.0       3600.0
# 34.0                         17.1              185.0       3400.0
# 34.1                         18.1              193.0       3475.0
# ...                           ...                ...          ...
# 55.1                         16.0              230.0       5850.0
# 55.8                         19.8              207.0       4000.0
# 55.9                         17.0              228.0       5600.0
# 58.0                         17.8              181.0       3700.0
# 59.6                         17.0              230.0       6050.0
#
# [164 rows x 3 columns]
